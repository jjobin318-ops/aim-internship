# %%
# To store your name and print it in upper case
name = "Adhil"
print(name.upper())
# Out:
# ADHIL

# %%
# To store your name and print it in upper case
name = "Amal"
print(name.upper())
# Out:
# AMAL

# %%
# To store your name and print it in upper case
name = "Alen"
print(name.upper())
# Out:
# ALEN

# %%
# To store your name and print it in upper case
name = "Vaishnav"
print(name.upper())
# Out:
# VAISHNAV

# %%
# To print first and last character of a sentence
sentence = "Python is easy"
print("First character:",sentence[0])
print("Last Character:",sentence[-1])
# Out:
# First character: P
# Last Character: y

# %%
# To print total number of caharcters
text = "Python Programming"
print(len(text))
# Out:
# 18

# %%
# To capitalize first letter of each words
msg = "hello world"
print(msg.title())
# Out:
# Hello World

# %%
# To replace spaces in a sentence with -
line = "To replace spaces in a sentence"
print(line.replace("","-"))
# Out:
# -T-o- -r-e-p-l-a-c-e- -s-p-a-c-e-s- -i-n- -a- -s-e-n-t-e-n-c-e-

# %%
# To create a string"banana" and count a in it
fruit = "banana"
print(fruit.count("a"))
# Out:
# 3

# %%
# To store your favorite movie name in a string and print in lowecase
movie = "DOCTOR STRANGE"
print(movie.lower())
# Out:
# doctor strange

# %%
# To write a program to check whether the word "Python" exists inside the 
# sentence "I am learning Python today"
s = "I am learning Python today"
print("Python" in s)
# Out:
# True

# %%
# To create a string with extra spaces at the beginning and end then remove 
# the spaces and print the result
word = "   Hello World   "
print(word.strip())
# Out:
# Hello World

# %%
# To store "apple,mango,orange" in a string and split it into seperate fruits
#  using a string meathod
fruits = "apple,mango,orange"
print(fruits.split("."))
# Out:
# ['apple,mango,orange']
