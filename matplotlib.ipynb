# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 277.6 kB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 357.1 kB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/adhilmuhammed/Library/Python/3.12/lib/python/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /Users/adhilmuhammed/Library/Python/3.12/lib/python/site-packages (from matplotlib) (26.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/adhilmuhammed/Library/Python/3.12/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/adhilmuhammed/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.0/274.0 kB 453.9 kB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.1 MB/s eta 0:00:0000:0100:010m
# Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 2.5 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 982.8 kB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 507.5 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color='green', linestyle='--', marker='o')
plt.title('My Plot')
plt.xlabel('X-axis')

plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = [1, 2, 3]
y1 = [1, 4, 9]
y2 = [1, 2, 3]
plt.plot(x, y1, label='squares')
plt.plot(x, y2, label='Linear')
plt.legend()
plt.show()

# %%
categories = ['A', 'B','C']
values = [5, 7, 3]
plt.bar(categories, values)
plt.show()

# %%
data = [1, 1, 2, 3, 3, 3, 4, 4, 5]
plt.hist(data, bins=5)
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y)
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot([1, 2, 3], [1, 2, 3])
plt.subplot(1, 2, 2)
plt.plot([1, 2, 3], [3, 2, 1])
plt.show()

# %%
plt.plot(x, y)
plt.savefig('plot.png')
