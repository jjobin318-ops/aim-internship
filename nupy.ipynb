# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %% [markdown]
# Creating Numpy Arrays

# %%
# From Python Lists
arr = np.array([1, 2, 3])
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])

# %%
# Special Arrays
np.zeros((3, 3))
np.ones((2, 4))
np.eye(3)
np.arange(0, 10, 2)
np.linspace(0, 1, 5)
np.random.rand(3, 2)
np.random.randn(3, 2)
# Out:
# array([[-0.26381106,  0.47863577],
#        [-1.03276644, -0.19676513],
#        [ 0.35409025,  0.00595965]])

# %% [markdown]
# Array Attributes

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %% [markdown]
# Array Operations

# %%
# Basic Math
a = np.array([1, 2, 3])

b = np.array([4, 5, 6])
a + b
a * b
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
# Matrix Multiplication
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
np.dot(A, B)
A @ B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
# Aggregation
arr = np.array([1, 2, 3, 4])
arr.sum()
arr.mean()
arr.max()
arr.min()
arr.std()
# Out:
# np.float64(1.118033988749895)

# %% [markdown]
# Indexing & Slicing

# %%
# 1D Arrays
arr = np.array([1, 2, 3, 4, 5])
arr[0]

arr[1:4]
arr[::2]
# Out:
# array([1, 3, 5])

# %%
# 2D Arrays
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0, 1]
arr[:, 1]
arr[1, :2]
# Out:
# array([4, 5])

# %%
# Boolean Indexing
arr = np.array([1, 2, 3, 4, 5])
mask = arr > 3
arr[mask]
# Out:
# array([4, 5])

# %% [markdown]
# Reshaping & Combining Arrays

# %%
# Reshape
arr = np.arange(6)
arr.reshape(2, 3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
# Concatenation
a = np.array([1, 2])
b = np.array([3, 4])
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4])

# %%
# Stacking
np.vstack((a, b))
np.hstack((a, b))
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# Broadcasting

# %%
a = np.array([1, 2, 3])
a + 5 # [6, 7, 8]
# Out:
# array([6, 7, 8])

# %% [markdown]
# Saving & Loading Arrays

# %%
# Save to a file
np.save('array.npy', arr)

# %%
# Load from a file
loaded_arr = np.load('array.npy')
